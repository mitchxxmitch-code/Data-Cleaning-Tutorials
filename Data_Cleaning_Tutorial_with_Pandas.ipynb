# %% [markdown]
# # Data Cleaning Tutorial with Pandas

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Import the data

# %%
survey_df = pd.read_csv("./Data/survey_results_public.csv")
survey_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode  ...              Age Gender Trans                Sexuality  \
# 0           NaN  ...  25-34 years old    Man    No  Straight / Heterosexual
# 1             7  ...  18-24 years old    Man    No  Straight / Heterosexual
# 2           NaN  ...  18-24 years old    Man    No        Prefer not to say
# 3           NaN  ...  35-44 years old    Man    No  Straight / Heterosexual
# 4            17  ...  25-34 years old    Man    No                      NaN
# ...         ...  ...              ...    ...   ...                      ...
# 83434         6  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83435         4  ...  18-24 years old    Man    No  Straight / Heterosexual
# 83436        10  ...  25-34 years old    Man    No                      NaN
# 83437         5  ...  25-34 years old    Man    No  Straight / Heterosexual
# 83438        14  ...  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 0      Appropriate in length                        Easy             62268.0
# 1      Appropriate in length                        Easy                 NaN
# 2      Appropriate in length                        Easy                 NaN
# 3      Appropriate in length  Neither easy nor difficult                 NaN
# 4      Appropriate in length                        Easy                 NaN
# ...                      ...                         ...                 ...
# 83434  Appropriate in length                        Easy            160500.0
# 83435  Appropriate in length                        Easy              3960.0
# 83436  Appropriate in length  Neither easy nor difficult             90000.0
# 83437  Appropriate in length  Neither easy nor difficult            816816.0
# 83438  Appropriate in length                        Easy             21168.0
#
# [83439 rows x 48 columns]

# %% [markdown]
# # Part 1

# %%
survey_df.shape
# Out:
# (83439, 48)

# %%
pd.set_option('display.max_columns', 50)
survey_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
schema_df = pd.read_csv("./Data/survey_results_schema.csv")
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
# default = 5
survey_df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
# 6                                I prefer not to say
# 7                                 Student, full-time
# 8                                 Employed part-time
# 9                                 Employed full-time
#
#                                              Country       US_State  \
# 0                                           Slovakia            NaN
# 1                                        Netherlands            NaN
# 2                                 Russian Federation            NaN
# 3                                            Austria            NaN
# 4  United Kingdom of Great Britain and Northern I...            NaN
# 5                           United States of America        Georgia
# 6                           United States of America  New Hampshire
# 7                                           Malaysia            NaN
# 8                                              India            NaN
# 9                                             Sweden            NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4    England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6        NaN  Secondary school (e.g. American high school, G...
# 7        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
# 2  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 3  11 - 17 years                                                NaN       NaN
# 4   5 - 10 years                            Friend or family member        17
# 5  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 6  11 - 17 years  Other online resources (ex: videos, blogs, etc...         3
# 7  11 - 17 years             School;Online Courses or Certification         4
# 8  18 - 24 years                                    Coding Bootcamp         6
# 9  11 - 17 years                                             School         7
#
#   YearsCodePro                                            DevType  \
# 0          NaN                                  Developer, mobile
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                               Developer, front-end
# 4           10  Developer, desktop or enterprise applications;...
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8            4                               Developer, front-end
# 9            4      Data scientist or machine learning specialist
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
# 5                                                NaN                  NaN
# 6                                                NaN                  NaN
# 7                                                NaN                  NaN
# 8                           10,000 or more employees    INR\tIndian rupee
# 9                                 10 to 19 employees   SEK\tSwedish krona
#
#    CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 0     4800.0  Monthly      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                                  JavaScript;Python
# 2        NaN      NaN                           Assembly;C;Python;R;Rust
# 3        NaN  Monthly                              JavaScript;TypeScript
# 4        NaN      NaN                     Bash/Shell;HTML/CSS;Python;SQL
# 5        NaN      NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6        NaN      NaN                                HTML/CSS;JavaScript
# 7        NaN      NaN        HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 8        NaN  Monthly                                HTML/CSS;JavaScript
# 9    42000.0  Monthly                                         C++;Python
#
#                               LanguageWantToWorkWith  \
# 0                                              Swift
# 1                                                NaN
# 2                                  Julia;Python;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# 5  C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                            HTML/CSS;JavaScript;PHP
# 7                                               Ruby
# 8                                HTML/CSS;JavaScript
# 9                                     Haskell;Python
#
#            DatabaseHaveWorkedWith  \
# 0               PostgreSQL;SQLite
# 1                      PostgreSQL
# 2                          SQLite
# 3                             NaN
# 4  Elasticsearch;PostgreSQL;Redis
# 5         MySQL;PostgreSQL;SQLite
# 6                             NaN
# 7         MySQL;PostgreSQL;SQLite
# 8                      PostgreSQL
# 9                      PostgreSQL
#
#                               DatabaseWantToWorkWith  PlatformHaveWorkedWith  \
# 0                                             SQLite                     NaN
# 1                                                NaN                     NaN
# 2                                             SQLite                  Heroku
# 3                                                NaN                     NaN
# 4           Cassandra;Elasticsearch;PostgreSQL;Redis                     NaN
# 5  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...                     NaN
# 6                                                NaN                     NaN
# 7                                         PostgreSQL  Heroku;Microsoft Azure
# 8                                         PostgreSQL                     AWS
# 9                                                NaN                     NaN
#
#   PlatformWantToWorkWith           WebframeHaveWorkedWith  \
# 0                    NaN                  Laravel;Symfony
# 1                    NaN             Angular;Flask;Vue.js
# 2                    NaN                            Flask
# 3                    NaN                   Angular;jQuery
# 4                    NaN                            Flask
# 5                    NaN    Express;Flask;jQuery;React.js
# 6                    NaN                           jQuery
# 7                 Heroku  Angular.js;jQuery;Ruby on Rails
# 8                    NaN                   Django;FastAPI
# 9                    NaN                              NaN
#
#           WebframeWantToWorkWith                       MiscTechHaveWorkedWith  \
# 0                            NaN                                          NaN
# 1                            NaN                                      Cordova
# 2                          Flask        NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                 Angular;jQuery                                          NaN
# 4                          Flask             Apache Spark;Hadoop;NumPy;Pandas
# 5  Express;Flask;jQuery;React.js  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                         jQuery                                          NaN
# 7                  Ruby on Rails                                          NaN
# 8                 Django;FastAPI                                          NaN
# 9                            NaN  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                               MiscTechWantToWorkWith  \
# 0                                                NaN
# 1                                                NaN
# 2        Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                NaN
# 4                                Hadoop;NumPy;Pandas
# 5  Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9               Keras;NumPy;TensorFlow;Torch/PyTorch
#
#       ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 0                         NaN                                NaN
# 1             Docker;Git;Yarn                                Git
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4  Docker;Git;Kubernetes;Yarn         Docker;Git;Kubernetes;Yarn
# 5                         Git  Docker;Git;Unity 3D;Unreal Engine
# 6                         NaN                                NaN
# 7                         NaN                                NaN
# 8                  Docker;Git              Docker;Git;Kubernetes
# 9                         Git                                Git
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# 5  IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                NaN
# 7                    Sublime Text;Visual Studio Code
# 8                               PyCharm;Sublime Text
# 9             IPython/Jupyter;Vim;Visual Studio Code
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# 5  Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 6                                                NaN      Windows
# 7                    Sublime Text;Visual Studio Code  Linux-based
# 8                               PyCharm;Sublime Text      Windows
# 9       Emacs;IPython/Jupyter;Vim;Visual Studio Code  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
# 5  Visit Stack Overflow;Go for a walk or other ph...
# 6  Call a coworker or friend;Visit Stack Overflow...
# 7  Visit Stack Overflow;Go for a walk or other ph...
# 8               Visit Stack Overflow;Google it;Panic
# 9  Call a coworker or friend;Visit Stack Overflow...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 5  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 6                 Stack Overflow   Daily or almost daily       Yes
# 7  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 8  Stack Overflow;Stack Exchange    A few times per week       Yes
# 9  Stack Overflow;Stack Exchange  Multiple times per day       Yes
#
#                                           SOPartFreq           SOComm  \
# 0                    A few times per month or weekly  Yes, definitely
# 1                              Daily or almost daily  Yes, definitely
# 2                             Multiple times per day  Yes, definitely
# 3                              Daily or almost daily          Neutral
# 4                               A few times per week    Yes, somewhat
# 5  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 6                               A few times per week    Yes, somewhat
# 7  I have never participated in Q&A on Stack Over...   No, not at all
# 8                Less than once per month or monthly  Yes, definitely
# 9                              Daily or almost daily    Yes, somewhat
#
#   NEWOtherComms                Age             Gender Trans  \
# 0            No    25-34 years old                Man    No
# 1            No    18-24 years old                Man    No
# 2           Yes    18-24 years old                Man    No
# 3            No    35-44 years old                Man    No
# 4            No    25-34 years old                Man    No
# 5            No    18-24 years old  Prefer not to say    No
# 6            No  Prefer not to say  Prefer not to say    No
# 7           Yes    18-24 years old              Woman    No
# 8            No    25-34 years old                Man    No
# 9            No    25-34 years old                Man    No
#
#                  Sexuality                                          Ethnicity  \
# 0  Straight / Heterosexual                       White or of European descent
# 1  Straight / Heterosexual                       White or of European descent
# 2        Prefer not to say                                  Prefer not to say
# 3  Straight / Heterosexual                       White or of European descent
# 4                      NaN                       White or of European descent
# 5  Straight / Heterosexual                                  Prefer not to say
# 6                      NaN                                       I don't know
# 7  Straight / Heterosexual  White or of European descent;Multiracial;South...
# 8                      NaN                                        South Asian
# 9  Straight / Heterosexual                       White or of European descent
#
#                  Accessibility  \
# 0            None of the above
# 1            None of the above
# 2            None of the above
# 3  I am deaf / hard of hearing
# 4            None of the above
# 5            None of the above
# 6            None of the above
# 7            None of the above
# 8                          NaN
# 9            None of the above
#
#                                         MentalHealth           SurveyLength  \
# 0                                  None of the above  Appropriate in length
# 1                                  None of the above  Appropriate in length
# 2                                  None of the above  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                                NaN  Appropriate in length
# 5  I have a concentration and/or memory disorder ...               Too long
# 6                                  None of the above  Appropriate in length
# 7                                  None of the above  Appropriate in length
# 8  I have a concentration and/or memory disorder ...  Appropriate in length
# 9                                  None of the above  Appropriate in length
#
#                    SurveyEase  ConvertedCompYearly
# 0                        Easy              62268.0
# 1                        Easy                  NaN
# 2                        Easy                  NaN
# 3  Neither easy nor difficult                  NaN
# 4                        Easy                  NaN
# 5  Neither easy nor difficult                  NaN
# 6  Neither easy nor difficult                  NaN
# 7                        Easy                  NaN
# 8                        Easy                  NaN
# 9  Neither easy nor difficult              51552.0

# %%
survey_df.tail(7)
# Out:
#        ResponseId                      MainBranch  \
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83432                    Canada         NaN        NaN
# 83433                    Brazil         NaN        NaN
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# 83438                    Brazil         NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83432                                             School         5
# 83433  Online Forum;Online Courses or Certification;O...        15
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#            YearsCodePro                                            DevType  \
# 83432  Less than 1 year                                Developer, back-end
# 83433                11  Developer, mobile;Developer, front-end;Develop...
# 83434                 5                                Developer, back-end
# 83435                 2                              Developer, full-stack
# 83436                 4  Data scientist or machine learning specialist;...
# 83437                 3                                Developer, back-end
# 83438                 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83432                           10,000 or more employees
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83432         CAD\tCanadian dollar   106000.0   Yearly
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 83432                                           Ruby
# 83433  Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83432                               Java;Ruby;TypeScript
# 83433                                             Kotlin
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 83432                                  MySQL;PostgreSQL
# 83433                     Firebase;MongoDB;MySQL;SQLite
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83432                                                NaN
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#              PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 83432  Google Cloud Platform;Heroku                    NaN
# 83433                           NaN                    NaN
# 83434                           AWS                    AWS
# 83435                           NaN                    NaN
# 83436     AWS;Google Cloud Platform                    AWS
# 83437                        Heroku       AWS;DigitalOcean
# 83438               Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 83432           Flask;React.js;Ruby on Rails;Vue.js
# 83433                                      React.js
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 83432  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83433                           React Native
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 83432                                                NaN
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 83432    Docker;Git;Kubernetes;Yarn                              NaN
# 83433               Docker;Git;Yarn                       Docker;Git
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 83432                                                NaN        MacOS
# 83433                               Android Studio;Xcode        MacOS
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83432                      Stack Overflow;Stack Exchange
# 83433                                     Stack Overflow
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 83432            Daily or almost daily        No
# 83433            Daily or almost daily       Yes
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq          SOComm  \
# 83432                                                NaN  No, not really
# 83433                    A few times per month or weekly   Yes, somewhat
# 83434                                                NaN  No, not at all
# 83435  I have never participated in Q&A on Stack Over...   Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...  No, not really
# 83437                Less than once per month or monthly  No, not really
# 83438                               A few times per week   Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 83432            No  18-24 years old  Woman    No  Straight / Heterosexual
# 83433            No  25-34 years old    Man    No  Straight / Heterosexual
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity      Accessibility  \
# 83432                    East Asian  None of the above
# 83433        Hispanic or Latino/a/x  None of the above
# 83434  White or of European descent  None of the above
# 83435   Black or of African descent  None of the above
# 83436  White or of European descent  None of the above
# 83437  White or of European descent  None of the above
# 83438        Hispanic or Latino/a/x  None of the above
#
#                                             MentalHealth  \
# 83432                                  None of the above
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83432  Appropriate in length                        Easy              80169.0
# 83433  Appropriate in length                        Easy              18326.0
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %% [markdown]
# ## Excourse Data Structures

# %%
peoples_dict = {
    "First_Name": ["Max", "John", "Anna"],
    "Last_Name": ["Mason", "Doe", "Adams"],
    "Email": ["max_mason939sd39@gmail.com", "john_doe939ds39@gmail.com", "anna_adams284s72d8@gmail.com"]
}

# %%
peoples_df = pd.DataFrame.from_dict(peoples_dict)
peoples_df
# Out:
#   First_Name Last_Name                         Email
# 0        Max     Mason    max_mason939sd39@gmail.com
# 1       John       Doe     john_doe939ds39@gmail.com
# 2       Anna     Adams  anna_adams284s72d8@gmail.com

# %%
type(peoples_df["Email"])
# Out:
# pandas.core.series.Series

# %%
peoples_df["Last_Name"]
# Out:
# 0    Mason
# 1      Doe
# 2    Adams
# Name: Last_Name, dtype: object

# %%
peoples_df.Last_Name
# Out:
# 0    Mason
# 1      Doe
# 2    Adams
# Name: Last_Name, dtype: object

# %%
peoples_df[["First_Name", "Last_Name"]]
# Out:
#   First_Name Last_Name
# 0        Max     Mason
# 1       John       Doe
# 2       Anna     Adams

# %%
type(peoples_df[["First_Name", "Last_Name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
peoples_df.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Email'], dtype='object')

# %%
peoples_df.iloc[0]
# Out:
# First_Name                           Max
# Last_Name                          Mason
# Email         max_mason939sd39@gmail.com
# Name: 0, dtype: object

# %%
peoples_df.iloc[0,1]
# Out:
# 'Mason'

# %%
peoples_df.iloc[[0,1],[1,2]]
# Out:
#   Last_Name                       Email
# 0     Mason  max_mason939sd39@gmail.com
# 1       Doe   john_doe939ds39@gmail.com

# %%
peoples_df.loc[[0,1], ["Last_Name", "Email"]]
# Out:
#   Last_Name                       Email
# 0     Mason  max_mason939sd39@gmail.com
# 1       Doe   john_doe939ds39@gmail.com

# %% [markdown]
# # Part 2

# %% [markdown]
# ## Back to the Stackoverflow Survey

# %%
survey_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
survey_df.sample(20)
# Out:
#        ResponseId                                         MainBranch  \
# 72879       72880                     I am a developer by profession
# 15115       15116                     I am a developer by profession
# 34984       34985                     I am a developer by profession
# 51699       51700                     I am a developer by profession
# 81790       81791                     I am a developer by profession
# 62857       62858             I am a student who is learning to code
# 4941         4942  I used to be a developer by profession, but no...
# 62676       62677                     I am a developer by profession
# 8735         8736                     I am a developer by profession
# 24658       24659                     I am a developer by profession
# 24891       24892                     I am a developer by profession
# 20286       20287                     I am a developer by profession
# 33216       33217                     I am a developer by profession
# 13775       13776                     I am a developer by profession
# 47949       47950                     I am a developer by profession
# 80071       80072                        I code primarily as a hobby
# 53861       53862                     I am a developer by profession
# 33855       33856                     I am a developer by profession
# 16303       16304                     I am a developer by profession
# 38915       38916             I am a student who is learning to code
#
#                                               Employment  \
# 72879                                 Employed full-time
# 15115                                 Employed full-time
# 34984                                 Employed full-time
# 51699                                 Employed full-time
# 81790                                 Employed full-time
# 62857             Not employed, and not looking for work
# 4941                                             Retired
# 62676  Independent contractor, freelancer, or self-em...
# 8735                                  Employed full-time
# 24658  Independent contractor, freelancer, or self-em...
# 24891                                 Employed full-time
# 20286                                 Employed full-time
# 33216                                 Employed full-time
# 13775                                 Employed full-time
# 47949  Independent contractor, freelancer, or self-em...
# 80071                                I prefer not to say
# 53861                                 Employed full-time
# 33855                                 Employed full-time
# 16303                                 Employed full-time
# 38915                                 Student, full-time
#
#                                                  Country       US_State  \
# 72879                                            Germany            NaN
# 15115  United Kingdom of Great Britain and Northern I...            NaN
# 34984                           United States of America           Ohio
# 51699                                             France            NaN
# 81790                           United States of America       New York
# 62857                                             Turkey            NaN
# 4941                            United States of America       Missouri
# 62676                           United States of America        Georgia
# 8735   United Kingdom of Great Britain and Northern I...            NaN
# 24658                                             Sweden            NaN
# 24891                                         Bangladesh            NaN
# 20286                                             Brazil            NaN
# 33216                                             Serbia            NaN
# 13775  United Kingdom of Great Britain and Northern I...            NaN
# 47949                                          Australia            NaN
# 80071                                             Canada            NaN
# 53861                                           Viet Nam            NaN
# 33855                           United States of America  Massachusetts
# 16303                                              India            NaN
# 38915                       Iran, Islamic Republic of...            NaN
#
#       UK_Country                                            EdLevel  \
# 72879        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15115    England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34984        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 51699        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 81790        NaN                 Professional degree (JD, MD, etc.)
# 62857        NaN  Secondary school (e.g. American high school, G...
# 4941         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62676        NaN  Some college/university study without earning ...
# 8735     England       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24658        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24891        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20286        NaN  Some college/university study without earning ...
# 33216        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13775    England  Some college/university study without earning ...
# 47949        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 80071        NaN                                     Something else
# 53861        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33855        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 16303        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38915        NaN                Associate degree (A.A., A.S., etc.)
#
#           Age1stCode                                          LearnCode  \
# 72879  25 - 34 years  Other online resources (ex: videos, blogs, etc...
# 15115  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 34984  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 51699   5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 81790  18 - 24 years                                             School
# 62857  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4941   18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 62676  11 - 17 years                             Books / Physical media
# 8735    5 - 10 years                            Friend or family member
# 24658   5 - 10 years    Other online resources (ex: videos, blogs, etc)
# 24891  18 - 24 years                   Colleague;Books / Physical media
# 20286  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 33216  18 - 24 years             School;Online Courses or Certification
# 13775  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 47949  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 80071  11 - 17 years    Other online resources (ex: videos, blogs, etc)
# 53861  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 33855  11 - 17 years                      School;Books / Physical media
# 16303  18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 38915  11 - 17 years  Other online resources (ex: videos, blogs, etc...
#
#       YearsCode YearsCodePro  \
# 72879         5            4
# 15115        11           11
# 34984        15           10
# 51699        17            3
# 81790        22           18
# 62857         1          NaN
# 4941         45           40
# 62676        36           30
# 8735         22           20
# 24658         5            1
# 24891        10            6
# 20286        10            2
# 33216         4            3
# 13775        10            5
# 47949        15            7
# 80071         6          NaN
# 53861         6            1
# 33855        13            8
# 16303         4            2
# 38915         5          NaN
#
#                                                  DevType  \
# 72879                                  Developer, mobile
# 15115  Developer, desktop or enterprise applications;...
# 34984  Developer, desktop or enterprise applications;...
# 51699  Developer, back-end;Developer, embedded applic...
# 81790  Developer, front-end;Developer, full-stack;Dev...
# 62857                                                NaN
# 4941                                                 NaN
# 62676                              Developer, full-stack
# 8735             Developer, back-end;Engineering manager
# 24658  Developer, mobile;Developer, front-end;Develop...
# 24891         Developer, front-end;Developer, full-stack
# 20286                              Developer, full-stack
# 33216                                Developer, back-end
# 13775  Developer, front-end;Developer, full-stack;Dev...
# 47949  Developer, full-stack;Data scientist or machin...
# 80071                                                NaN
# 53861                                Developer, back-end
# 33855  Data scientist or machine learning specialist;...
# 16303  Developer, desktop or enterprise applications;...
# 38915                                                NaN
#
#                                                  OrgSize  \
# 72879                               100 to 499 employees
# 15115                                       I don’t know
# 34984                           1,000 to 4,999 employees
# 51699                           1,000 to 4,999 employees
# 81790                                   2 to 9 employees
# 62857                                                NaN
# 4941                                                 NaN
# 62676  Just me - I am a freelancer, sole proprietor, ...
# 8735                            10,000 or more employees
# 24658                                   2 to 9 employees
# 24891                                 10 to 19 employees
# 20286                                   2 to 9 employees
# 33216                                 20 to 99 employees
# 13775                                   2 to 9 employees
# 47949  Just me - I am a freelancer, sole proprietor, ...
# 80071                                                NaN
# 53861                                       I don’t know
# 33855                           10,000 or more employees
# 16303                           1,000 to 4,999 employees
# 38915                                                NaN
#
#                         Currency   CompTotal CompFreq  \
# 72879          EUR European Euro      4000.0  Monthly
# 15115        GBP\tPound sterling    100000.0   Yearly
# 34984  USD\tUnited States dollar    145000.0   Yearly
# 51699          EUR European Euro      5000.0  Monthly
# 81790  USD\tUnited States dollar     60000.0   Yearly
# 62857                        NaN         NaN      NaN
# 4941                         NaN         NaN      NaN
# 62676  USD\tUnited States dollar    150000.0   Yearly
# 8735         GBP\tPound sterling    110000.0   Yearly
# 24658         SEK\tSwedish krona         0.0      NaN
# 24891      BDT\tBangladeshi taka         NaN   Yearly
# 20286        BRL\tBrazilian real      2200.0  Monthly
# 33216         RSD\tSerbian dinar    220000.0  Monthly
# 13775        GBP\tPound sterling     36000.0   Yearly
# 47949     AUD\tAustralian dollar      6000.0  Monthly
# 80071                        NaN         NaN      NaN
# 53861       VND\tVietnamese dong  70000000.0  Monthly
# 33855  USD\tUnited States dollar         NaN      NaN
# 16303          INR\tIndian rupee    628000.0   Yearly
# 38915                        NaN         NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 72879                                                 C#
# 15115                                          C#;F#;SQL
# 34984                Bash/Shell;C#;Python;SQL;TypeScript
# 51699  Bash/Shell;C;C#;C++;JavaScript;PHP;Python;Type...
# 81790                         C#;HTML/CSS;JavaScript;SQL
# 62857                        HTML/CSS;JavaScript;PHP;SQL
# 4941   APL;Assembly;C;C#;C++;Delphi;Java;JavaScript;L...
# 62676  Bash/Shell;C;C#;HTML/CSS;Java;JavaScript;Node....
# 8735                                     Java;JavaScript
# 24658  C#;HTML/CSS;Java;JavaScript;Kotlin;Node.js;PHP...
# 24891  C;C++;HTML/CSS;Java;JavaScript;Node.js;PHP;Pow...
# 20286                 HTML/CSS;JavaScript;PHP;TypeScript
# 33216                                                 C#
# 13775             HTML/CSS;JavaScript;Node.js;Python;SQL
# 47949  Bash/Shell;C;C#;C++;HTML/CSS;JavaScript;Matlab...
# 80071                                                 C#
# 53861  Bash/Shell;JavaScript;Node.js;Python;SQL;TypeS...
# 33855                                  Bash/Shell;Python
# 16303                    Groovy;HTML/CSS;Java;JavaScript
# 38915  Bash/Shell;C#;C++;HTML/CSS;JavaScript;PHP;Pyth...
#
#                                   LanguageWantToWorkWith  \
# 72879                                              Swift
# 15115                                    F#;Haskell;Rust
# 34984            Bash/Shell;Elixir;Julia;LISP;Python;SQL
# 51699                                         C++;Python
# 81790      C#;HTML/CSS;JavaScript;Node.js;SQL;TypeScript
# 62857                        HTML/CSS;JavaScript;PHP;SQL
# 4941                             Bash/Shell;Python;R;SQL
# 62676  Bash/Shell;C#;HTML/CSS;Java;JavaScript;Node.js...
# 8735                                           Java;Rust
# 24658  C#;Elixir;HTML/CSS;Java;JavaScript;Kotlin;Node...
# 24891                                  Python;TypeScript
# 20286    HTML/CSS;Java;JavaScript;Node.js;PHP;TypeScript
# 33216                                      C#;TypeScript
# 13775  HTML/CSS;JavaScript;Node.js;Python;SQL;TypeScript
# 47949                                                 F#
# 80071                               Assembly;C;C#;Python
# 53861                           Bash/Shell;Go;Python;SQL
# 33855                                  Bash/Shell;Python
# 16303                                     Node.js;Python
# 38915  Bash/Shell;C;C++;Clojure;Haskell;Java;LISP;Pyt...
#
#                                   DatabaseHaveWorkedWith  \
# 72879                                                NaN
# 15115                 Elasticsearch;Microsoft SQL Server
# 34984              Microsoft SQL Server;PostgreSQL;Redis
# 51699                              MariaDB;Oracle;SQLite
# 81790                               Microsoft SQL Server
# 62857                                      MariaDB;MySQL
# 4941   IBM DB2;Microsoft SQL Server;MongoDB;MySQL;Ora...
# 62676                 IBM DB2;Microsoft SQL Server;MySQL
# 8735                                    PostgreSQL;Redis
# 24658             MariaDB;MongoDB;MySQL;PostgreSQL;Redis
# 24891                       MariaDB;MongoDB;MySQL;SQLite
# 20286                                   MySQL;PostgreSQL
# 33216                 Microsoft SQL Server;MongoDB;MySQL
# 13775                               MongoDB;MySQL;SQLite
# 47949                                                NaN
# 80071                                                NaN
# 53861                                MariaDB;MySQL;Redis
# 33855                                                NaN
# 16303                         Microsoft SQL Server;MySQL
# 38915                                     MariaDB;SQLite
#
#                          DatabaseWantToWorkWith  \
# 72879                                       NaN
# 15115            Elasticsearch;PostgreSQL;Redis
# 34984                                     Redis
# 51699                                PostgreSQL
# 81790        Elasticsearch;Microsoft SQL Server
# 62857                     MariaDB;MongoDB;MySQL
# 4941           MongoDB;Oracle;PostgreSQL;SQLite
# 62676                Microsoft SQL Server;MySQL
# 8735                           PostgreSQL;Redis
# 24658                             MongoDB;Redis
# 24891                                       NaN
# 20286            MongoDB;MySQL;PostgreSQL;Redis
# 33216        Microsoft SQL Server;MongoDB;MySQL
# 13775  Elasticsearch;MongoDB;MySQL;Redis;SQLite
# 47949                                       NaN
# 80071                                       NaN
# 53861                                     Redis
# 33855                                       NaN
# 16303              Microsoft SQL Server;MongoDB
# 38915                              Redis;SQLite
#
#                                  PlatformHaveWorkedWith  \
# 72879                                               NaN
# 15115                                   Microsoft Azure
# 34984  AWS;Google Cloud Platform;Heroku;Microsoft Azure
# 51699                                               NaN
# 81790                                               NaN
# 62857                                               NaN
# 4941                                                AWS
# 62676                                      DigitalOcean
# 8735                                                AWS
# 24658                      Google Cloud Platform;Heroku
# 24891                                               NaN
# 20286                                               NaN
# 33216                                   Microsoft Azure
# 13775                                               AWS
# 47949                                   Microsoft Azure
# 80071                                               NaN
# 53861                                            Heroku
# 33855                             Google Cloud Platform
# 16303                               IBM Cloud or Watson
# 38915                                               NaN
#
#                     PlatformWantToWorkWith  \
# 72879                                  NaN
# 15115                      Microsoft Azure
# 34984                                  AWS
# 51699                                  NaN
# 81790                                  NaN
# 62857                                  NaN
# 4941                                   AWS
# 62676  DigitalOcean;Heroku;Microsoft Azure
# 8735                                   AWS
# 24658                                  NaN
# 24891                                  NaN
# 20286                                  NaN
# 33216                  AWS;Microsoft Azure
# 13775                                  AWS
# 47949                                  NaN
# 80071                                  NaN
# 53861            AWS;Google Cloud Platform
# 33855                Google Cloud Platform
# 16303                  AWS;Microsoft Azure
# 38915                                  NaN
#
#                               WebframeHaveWorkedWith  \
# 72879                                            NaN
# 15115                                  ASP.NET Core
# 34984            ASP.NET Core ;Django;Flask;React.js
# 51699                     ASP.NET Core ;Flask;Vue.js
# 81790                                 ASP.NET;jQuery
# 62857                                         jQuery
# 4941                                          Drupal
# 62676  ASP.NET;ASP.NET Core ;Express;jQuery;React.js
# 8735                                 React.js;Spring
# 24658                                 Express;Vue.js
# 24891                 jQuery;Laravel;React.js;Vue.js
# 20286                                jQuery;React.js
# 33216                          Angular;ASP.NET Core
# 13775           Django;Express;Flask;Gatsby;React.js
# 47949                                            NaN
# 80071                                            NaN
# 53861                                 Express;Vue.js
# 33855                                            NaN
# 16303                     Angular.js;React.js;Spring
# 38915                           Flask;jQuery;Laravel
#
#                                   WebframeWantToWorkWith  \
# 72879                                                NaN
# 15115                                      ASP.NET Core
# 34984                                                NaN
# 51699                                       Flask;Vue.js
# 81790                            ASP.NET;jQuery;React.js
# 62857                                    jQuery;React.js
# 4941                                       Django;Drupal
# 62676              ASP.NET Core ;Express;jQuery;React.js
# 8735                                              Spring
# 24658                            Express;React.js;Vue.js
# 24891                                                NaN
# 20286                            Express;React.js;Spring
# 33216                              Angular;ASP.NET Core
# 13775  Django;Express;Flask;Gatsby;React.js;Svelte;Vu...
# 47949                                                NaN
# 80071                                                NaN
# 53861                                                NaN
# 33855                                                NaN
# 16303                         Angular.js;React.js;Spring
# 38915                               Django;Flask;Laravel
#
#                                   MiscTechHaveWorkedWith  \
# 72879                                            Flutter
# 15115                                     .NET Framework
# 34984                                 .NET Core / .NET 5
# 51699                                 .NET Core / .NET 5
# 81790                                     .NET Framework
# 62857                                                NaN
# 4941                                                 NaN
# 62676                  .NET Framework;.NET Core / .NET 5
# 8735                                                 NaN
# 24658                                                NaN
# 24891                                                NaN
# 20286                                                NaN
# 33216                                 .NET Core / .NET 5
# 13775                                       React Native
# 47949  .NET Framework;.NET Core / .NET 5;Keras;Qt;Ten...
# 80071                  .NET Framework;.NET Core / .NET 5
# 53861                                                NaN
# 33855                      Keras;NumPy;Pandas;TensorFlow
# 16303                                                NaN
# 38915                                      Flutter;NumPy
#
#                   MiscTechWantToWorkWith          ToolsTechHaveWorkedWith  \
# 72879  .NET Framework;.NET Core / .NET 5                              NaN
# 15115                 .NET Core / .NET 5                              Git
# 34984            NumPy;Pandas;TensorFlow  Docker;Git;Kubernetes;Terraform
# 51699                 .NET Core / .NET 5                       Docker;Git
# 81790                     .NET Framework                              NaN
# 62857                                NaN                              Git
# 4941                                 NaN              Git;Kubernetes;Yarn
# 62676    .NET Core / .NET 5;React Native        Docker;Git;Puppet;Xamarin
# 8735                                 NaN                       Docker;Git
# 24658                                NaN               Docker;Git;Xamarin
# 24891                                NaN                              Git
# 20286                                NaN                         Git;Yarn
# 33216                 .NET Core / .NET 5                       Docker;Git
# 13775                                NaN             Deno;Docker;Git;Yarn
# 47949                                NaN                              Git
# 80071                 .NET Core / .NET 5                              NaN
# 53861                                NaN         Docker;Git;Unreal Engine
# 33855            NumPy;Pandas;TensorFlow                              Git
# 16303                                NaN                              Git
# 38915                              NumPy                              Git
#
#              ToolsTechWantToWorkWith  \
# 72879                            NaN
# 15115                     Docker;Git
# 34984          Docker;Git;Kubernetes
# 51699             Ansible;Docker;Git
# 81790                            NaN
# 62857                            Git
# 4941                             NaN
# 62676  Docker;Git;Kubernetes;Xamarin
# 8735           Docker;Git;Kubernetes
# 24658          Docker;Git;Kubernetes
# 24891                            NaN
# 20286                       Git;Yarn
# 33216                     Docker;Git
# 13775           Deno;Docker;Git;Yarn
# 47949                            NaN
# 80071                            NaN
# 53861       Docker;Git;Unreal Engine
# 33855                            Git
# 16303        Ansible;Chef;Docker;Git
# 38915                            Git
#
#                             NEWCollabToolsHaveWorkedWith  \
# 72879                                     Android Studio
# 15115                           Rider;Visual Studio Code
# 34984        IntelliJ;PyCharm;Sublime Text;Visual Studio
# 51699           IntelliJ;Sublime Text;Visual Studio Code
# 81790         Notepad++;Visual Studio;Visual Studio Code
# 62857                                 Visual Studio Code
# 4941                 Eclipse;IntelliJ;NetBeans;Notepad++
# 62676  Android Studio;IntelliJ;NetBeans;Notepad++;Rid...
# 8735                                            IntelliJ
# 24658  Android Studio;Eclipse;IntelliJ;Notepad++;Subl...
# 24891  Atom;Eclipse;NetBeans;Notepad++;PHPStorm;Subli...
# 20286                                 Visual Studio Code
# 33216                   Visual Studio;Visual Studio Code
# 13775                   PyCharm;Visual Studio Code;Xcode
# 47949              Emacs;Notepad++;PyCharm;Visual Studio
# 80071         Notepad++;Visual Studio;Visual Studio Code
# 53861      Sublime Text;Visual Studio;Visual Studio Code
# 33855                                   Sublime Text;Vim
# 16303               Eclipse;Notepad++;Visual Studio Code
# 38915                                          Emacs;Vim
#
#                             NEWCollabToolsWantToWorkWith  \
# 72879                                Visual Studio;Xcode
# 15115                  IntelliJ;Rider;Visual Studio Code
# 34984                               PyCharm;Sublime Text
# 51699           IntelliJ;Sublime Text;Visual Studio Code
# 81790         Notepad++;Visual Studio;Visual Studio Code
# 62857                                 Visual Studio Code
# 4941     Android Studio;Eclipse;IntelliJ;PyCharm;RStudio
# 62676  Android Studio;IntelliJ;PyCharm;Rider;Visual S...
# 8735                                            IntelliJ
# 24658  Android Studio;Sublime Text;Visual Studio;Visu...
# 24891                                            PyCharm
# 20286                                 Visual Studio Code
# 33216                   Visual Studio;Visual Studio Code
# 13775                                 Visual Studio Code
# 47949                                                NaN
# 80071         Notepad++;Visual Studio;Visual Studio Code
# 53861  Sublime Text;Vim;Visual Studio;Visual Studio C...
# 33855                          IntelliJ;Sublime Text;Vim
# 16303                        IntelliJ;Visual Studio Code
# 38915                                          Emacs;Vim
#
#                          OpSys  \
# 72879                    MacOS
# 15115                  Windows
# 34984  Other (please specify):
# 51699              Linux-based
# 81790                  Windows
# 62857                  Windows
# 4941               Linux-based
# 62676                    MacOS
# 8735                     MacOS
# 24658                  Windows
# 24891                  Windows
# 20286                  Windows
# 33216                  Windows
# 13775                    MacOS
# 47949                  Windows
# 80071                  Windows
# 53861                    MacOS
# 33855              Linux-based
# 16303                  Windows
# 38915              Linux-based
#
#                                                 NEWStuck  \
# 72879  Call a coworker or friend;Visit Stack Overflow...
# 15115  Call a coworker or friend;Visit Stack Overflow...
# 34984  Call a coworker or friend;Go for a walk or oth...
# 51699  Go for a walk or other physical activity;Googl...
# 81790  Visit Stack Overflow;Google it;Do other work a...
# 62857  Visit Stack Overflow;Google it;Watch help / tu...
# 4941   Call a coworker or friend;Visit Stack Overflow...
# 62676        Google it;Do other work and come back later
# 8735                                           Google it
# 24658                  Do other work and come back later
# 24891                     Visit Stack Overflow;Google it
# 20286  Call a coworker or friend;Visit Stack Overflow...
# 33216               Visit Stack Overflow;Google it;Panic
# 13775  Call a coworker or friend;Visit Stack Overflow...
# 47949  Visit Stack Overflow;Go for a walk or other ph...
# 80071  Visit Stack Overflow;Google it;Do other work a...
# 53861  Call a coworker or friend;Visit Stack Overflow...
# 33855                Call a coworker or friend;Google it
# 16303  Visit Stack Overflow;Go for a walk or other ph...
# 38915  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 72879                      Stack Overflow;Stack Exchange
# 15115                      Stack Overflow;Stack Exchange
# 34984                      Stack Overflow;Stack Exchange
# 51699                      Stack Overflow;Stack Exchange
# 81790                      Stack Overflow;Stack Exchange
# 62857                      Stack Overflow;Stack Exchange
# 4941                       Stack Overflow;Stack Exchange
# 62676                      Stack Overflow;Stack Exchange
# 8735                       Stack Overflow;Stack Exchange
# 24658                      Stack Overflow;Stack Exchange
# 24891  Stack Overflow;Stack Exchange;Stack Overflow f...
# 20286                                     Stack Overflow
# 33216                                     Stack Overflow
# 13775                      Stack Overflow;Stack Exchange
# 47949                      Stack Overflow;Stack Exchange
# 80071                      Stack Overflow;Stack Exchange
# 53861                      Stack Overflow;Stack Exchange
# 33855                      Stack Overflow;Stack Exchange
# 16303                      Stack Overflow;Stack Exchange
# 38915                      Stack Overflow;Stack Exchange
#
#                            SOVisitFreq                SOAccount  \
# 72879  A few times per month or weekly                      Yes
# 15115           Multiple times per day  Not sure/can't remember
# 34984  A few times per month or weekly                      Yes
# 51699            Daily or almost daily                      Yes
# 81790            Daily or almost daily                      Yes
# 62857           Multiple times per day                      Yes
# 4941             Daily or almost daily                      Yes
# 62676             A few times per week                      Yes
# 8735             Daily or almost daily  Not sure/can't remember
# 24658             A few times per week                      Yes
# 24891           Multiple times per day                      Yes
# 20286             A few times per week                      Yes
# 33216             A few times per week                       No
# 13775            Daily or almost daily                      Yes
# 47949           Multiple times per day                      Yes
# 80071           Multiple times per day                      Yes
# 53861             A few times per week                       No
# 33855           Multiple times per day                      Yes
# 16303           Multiple times per day                      Yes
# 38915            Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 72879  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 15115                                                NaN   No, not really
# 34984                    A few times per month or weekly    Yes, somewhat
# 51699                               A few times per week          Neutral
# 81790                Less than once per month or monthly   No, not really
# 62857                Less than once per month or monthly         Not sure
# 4941                               Daily or almost daily  Yes, definitely
# 62676                Less than once per month or monthly    Yes, somewhat
# 8735                                                 NaN   No, not really
# 24658  I have never participated in Q&A on Stack Over...          Neutral
# 24891                               A few times per week  Yes, definitely
# 20286                Less than once per month or monthly    Yes, somewhat
# 33216                                                NaN          Neutral
# 13775                Less than once per month or monthly          Neutral
# 47949                    A few times per month or weekly          Neutral
# 80071  I have never participated in Q&A on Stack Over...   No, not at all
# 53861                                                NaN   No, not really
# 33855                               A few times per week    Yes, somewhat
# 16303                Less than once per month or monthly  Yes, definitely
# 38915  I have never participated in Q&A on Stack Over...   No, not really
#
#       NEWOtherComms                 Age Gender Trans  \
# 72879            No     25-34 years old    Man    No
# 15115            No     25-34 years old    Man    No
# 34984            No     35-44 years old    Man    No
# 51699            No     25-34 years old    Man    No
# 81790            No     35-44 years old  Woman    No
# 62857           Yes  Under 18 years old    Man    No
# 4941             No   65 years or older    Man    No
# 62676            No     45-54 years old    Man    No
# 8735             No     35-44 years old    Man    No
# 24658           Yes     18-24 years old    Man    No
# 24891            No     25-34 years old    Man    No
# 20286            No     25-34 years old    Man    No
# 33216            No     25-34 years old  Woman    No
# 13775            No     25-34 years old    Man    No
# 47949           Yes     35-44 years old    Man    No
# 80071            No     18-24 years old    Man    No
# 53861           Yes     18-24 years old    Man    No
# 33855            No     25-34 years old    Man    No
# 16303            No     18-24 years old    Man    No
# 38915           Yes     18-24 years old    Man    No
#
#                       Sexuality  \
# 72879   Straight / Heterosexual
# 15115   Straight / Heterosexual
# 34984  Prefer to self-describe:
# 51699                       NaN
# 81790   Straight / Heterosexual
# 62857   Straight / Heterosexual
# 4941    Straight / Heterosexual
# 62676   Straight / Heterosexual
# 8735    Straight / Heterosexual
# 24658   Straight / Heterosexual
# 24891                       NaN
# 20286   Straight / Heterosexual
# 33216   Straight / Heterosexual
# 13775         Prefer not to say
# 47949   Straight / Heterosexual
# 80071         Prefer not to say
# 53861   Straight / Heterosexual
# 33855   Straight / Heterosexual
# 16303         Prefer not to say
# 38915   Straight / Heterosexual
#
#                                                Ethnicity      Accessibility  \
# 72879                                        South Asian                NaN
# 15115                       White or of European descent  None of the above
# 34984  White or of European descent;Or, in your own w...  None of the above
# 51699                       White or of European descent  None of the above
# 81790  White or of European descent;Hispanic or Latin...  None of the above
# 62857                                     Middle Eastern  None of the above
# 4941   White or of European descent;Indigenous (such ...  None of the above
# 62676                       White or of European descent  None of the above
# 8735                        White or of European descent  None of the above
# 24658                       White or of European descent  None of the above
# 24891                                        South Asian  None of the above
# 20286  White or of European descent;Multiracial;Hispa...  None of the above
# 33216                       White or of European descent  None of the above
# 13775                       White or of European descent  None of the above
# 47949                       White or of European descent  None of the above
# 80071                                  Prefer not to say  None of the above
# 53861                                    Southeast Asian  None of the above
# 33855                       White or of European descent  None of the above
# 16303                                       I don't know  None of the above
# 38915                                     Middle Eastern  None of the above
#
#                                             MentalHealth  \
# 72879                                                NaN
# 15115                                  None of the above
# 34984  I have a concentration and/or memory disorder ...
# 51699                                  None of the above
# 81790  I have a mood or emotional disorder (e.g. depr...
# 62857  I have a concentration and/or memory disorder ...
# 4941                                   None of the above
# 62676  I have a concentration and/or memory disorder ...
# 8735                                   None of the above
# 24658                             Or, in your own words:
# 24891                                  None of the above
# 20286  I have a mood or emotional disorder (e.g. depr...
# 33216                                  None of the above
# 13775                                  None of the above
# 47949                                  None of the above
# 80071  I have a concentration and/or memory disorder ...
# 53861                                  None of the above
# 33855                                                NaN
# 16303                                  None of the above
# 38915                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 72879  Appropriate in length                        Easy              51888.0
# 15115  Appropriate in length                        Easy             129259.0
# 34984                    NaN                        Easy             145000.0
# 51699  Appropriate in length                        Easy              64860.0
# 81790  Appropriate in length  Neither easy nor difficult              60000.0
# 62857              Too short                        Easy                  NaN
# 4941                Too long                        Easy                  NaN
# 62676  Appropriate in length                        Easy             150000.0
# 8735   Appropriate in length                        Easy             142185.0
# 24658              Too short                        Easy                  NaN
# 24891  Appropriate in length                        Easy                  NaN
# 20286  Appropriate in length                        Easy               6048.0
# 33216  Appropriate in length  Neither easy nor difficult              24228.0
# 13775              Too short                        Easy              46533.0
# 47949  Appropriate in length                        Easy              48108.0
# 80071  Appropriate in length  Neither easy nor difficult                  NaN
# 53861  Appropriate in length                        Easy              36228.0
# 33855                    NaN                         NaN                  NaN
# 16303  Appropriate in length                        Easy               8768.0
# 38915  Appropriate in length                        Easy                  NaN

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# ### Create filter/condition

# %%
filter_austria = survey_df["Country"] == "Austria"

# apply filter
austrian_devs = survey_df[filter_austria]
austrian_devs
# Out:
#        ResponseId                              MainBranch  \
# 3               4          I am a developer by profession
# 123           124          I am a developer by profession
# 254           255          I am a developer by profession
# 291           292  I am a student who is learning to code
# 339           340             I code primarily as a hobby
# ...           ...                                     ...
# 82849       82850          I am a developer by profession
# 82868       82869          I am a developer by profession
# 83048       83049          I am a developer by profession
# 83349       83350  I am a student who is learning to code
# 83419       83420          I am a developer by profession
#
#                                    Employment  Country US_State UK_Country  \
# 3                          Employed full-time  Austria      NaN        NaN
# 123                        Employed full-time  Austria      NaN        NaN
# 254                        Employed full-time  Austria      NaN        NaN
# 291                        Student, full-time  Austria      NaN        NaN
# 339    Not employed, and not looking for work  Austria      NaN        NaN
# ...                                       ...      ...      ...        ...
# 82849                      Employed full-time  Austria      NaN        NaN
# 82868                      Employed part-time  Austria      NaN        NaN
# 83048                      Employed full-time  Austria      NaN        NaN
# 83349                      Student, full-time  Austria      NaN        NaN
# 83419                      Employed full-time  Austria      NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 123      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
# 254                  Associate degree (A.A., A.S., etc.)  11 - 17 years
# 291    Secondary school (e.g. American high school, G...  11 - 17 years
# 339    Secondary school (e.g. American high school, G...   5 - 10 years
# ...                                                  ...            ...
# 82849    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 82868    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83048       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# 83349  Secondary school (e.g. American high school, G...  11 - 17 years
# 83419    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                                LearnCode YearsCode  \
# 3                                                    NaN       NaN
# 123                              Other (please specify):        12
# 254                                               School         9
# 291      Other online resources (ex: videos, blogs, etc)         6
# 339                              Friend or family member         6
# ...                                                  ...       ...
# 82849                      School;Books / Physical media        13
# 82868  Other online resources (ex: videos, blogs, etc...         4
# 83048  Coding Bootcamp;Other online resources (ex: vi...        15
# 83349  School;Online Forum;Online Courses or Certific...         5
# 83419  Other online resources (ex: videos, blogs, etc...        30
#
#       YearsCodePro                                            DevType  \
# 3              NaN                               Developer, front-end
# 123              8  Developer, QA or test;Developer, embedded appl...
# 254              2           Developer, front-end;Developer, back-end
# 291            NaN                                                NaN
# 339            NaN                                                NaN
# ...            ...                                                ...
# 82849            8  Developer, mobile;Developer, front-end;Develop...
# 82868            3                                Developer, back-end
# 83048            4  Developer, front-end;Developer, full-stack;Dev...
# 83349          NaN                                                NaN
# 83419           13  Developer, front-end;Developer, desktop or ent...
#
#                     OrgSize                Currency  CompTotal CompFreq  \
# 3      100 to 499 employees       EUR European Euro        NaN  Monthly
# 123    500 to 999 employees       EUR European Euro     4600.0  Monthly
# 254      20 to 99 employees       EUR European Euro        NaN  Monthly
# 291                     NaN                     NaN        NaN      NaN
# 339                     NaN                     NaN        NaN      NaN
# ...                     ...                     ...        ...      ...
# 82849    20 to 99 employees  AUD\tAustralian dollar   148000.0   Yearly
# 82868      2 to 9 employees       EUR European Euro        NaN      NaN
# 83048  500 to 999 employees       EUR European Euro     4400.0  Monthly
# 83349                   NaN                     NaN        NaN      NaN
# 83419  100 to 499 employees       EUR European Euro    77000.0   Yearly
#
#                                   LanguageHaveWorkedWith  \
# 3                                  JavaScript;TypeScript
# 123                                               Python
# 254                      HTML/CSS;JavaScript;Node.js;PHP
# 291     Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python
# 339    C#;C++;HTML/CSS;JavaScript;Node.js;Python;SQL;...
# ...                                                  ...
# 82849         Haskell;JavaScript;Node.js;Rust;TypeScript
# 82868                                  JavaScript;Python
# 83048  C#;C++;HTML/CSS;Java;JavaScript;Node.js;PHP;Po...
# 83349                       C;C++;Java;Python;Rust;Scala
# 83419  Groovy;HTML/CSS;Java;JavaScript;Node.js;PHP;Po...
#
#                                   LanguageWantToWorkWith  \
# 3                                  JavaScript;TypeScript
# 123                              Haskell;Rust;TypeScript
# 254                                                  NaN
# 291                                          Assembly;C#
# 339                                                  NaN
# ...                                                  ...
# 82849                            Haskell;Rust;TypeScript
# 82868                                             Python
# 83048  Go;HTML/CSS;JavaScript;Node.js;PHP;PowerShell;...
# 83349                             C;C++;Java;Python;Rust
# 83419  HTML/CSS;Java;JavaScript;Kotlin;Node.js;TypeSc...
#
#                                   DatabaseHaveWorkedWith  \
# 3                                                    NaN
# 123                                                  NaN
# 254                                                MySQL
# 291                                                  NaN
# 339                                           PostgreSQL
# ...                                                  ...
# 82849                  DynamoDB;Elasticsearch;PostgreSQL
# 82868                                         PostgreSQL
# 83048  Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 83349                                                NaN
# 83419  Elasticsearch;MariaDB;MySQL;Oracle;PostgreSQL;...
#
#                                   DatabaseWantToWorkWith  \
# 3                                                    NaN
# 123                                                  NaN
# 254                                                  NaN
# 291                                                  NaN
# 339                                                  NaN
# ...                                                  ...
# 82849                  DynamoDB;Elasticsearch;PostgreSQL
# 82868                                         PostgreSQL
# 83048       Elasticsearch;MariaDB;MySQL;PostgreSQL;Redis
# 83349                                                NaN
# 83419  Cassandra;Elasticsearch;MariaDB;MySQL;Oracle;P...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 3                            NaN                    NaN
# 123                          NaN                    NaN
# 254              Microsoft Azure                    NaN
# 291                          NaN                    NaN
# 339                       Heroku                    NaN
# ...                          ...                    ...
# 82849                        AWS                    AWS
# 82868                        NaN                    NaN
# 83048  AWS;Google Cloud Platform  Google Cloud Platform
# 83349                        NaN                    NaN
# 83419                        AWS    AWS;Microsoft Azure
#
#                       WebframeHaveWorkedWith  \
# 3                             Angular;jQuery
# 123                                      NaN
# 254                           jQuery;Laravel
# 291                                      NaN
# 339                                      NaN
# ...                                      ...
# 82849                       Express;React.js
# 82868                           Django;Flask
# 83048  ASP.NET Core ;Laravel;React.js;Vue.js
# 83349                                    NaN
# 83419                         Angular;Spring
#
#                               WebframeWantToWorkWith  \
# 3                                     Angular;jQuery
# 123                                              NaN
# 254                                              NaN
# 291                                              NaN
# 339                                              NaN
# ...                                              ...
# 82849                                       React.js
# 82868                                   Django;Flask
# 83048                                 Laravel;Vue.js
# 83349                                            NaN
# 83419  Angular;Express;React.js;Spring;Svelte;Vue.js
#
#                                   MiscTechHaveWorkedWith  \
# 3                                                    NaN
# 123                                                  NaN
# 254                                                  NaN
# 291                                                  NaN
# 339    .NET Framework;.NET Core / .NET 5;NumPy;Qt;Ten...
# ...                                                  ...
# 82849                                       React Native
# 82868                                                NaN
# 83048                      .NET Core / .NET 5;TensorFlow
# 83349                                       NumPy;Pandas
# 83419                                     .NET Framework
#
#       MiscTechWantToWorkWith                       ToolsTechHaveWorkedWith  \
# 3                        NaN                                           NaN
# 123                      NaN                            Ansible;Docker;Git
# 254                      NaN                                    Docker;Git
# 291                      NaN                                  Git;Unity 3D
# 339                      NaN                                           Git
# ...                      ...                                           ...
# 82849           React Native                                    Docker;Git
# 82868                    NaN                                    Docker;Git
# 83048          Qt;TensorFlow  Docker;Git;Kubernetes;Unity 3D;Unreal Engine
# 83349           NumPy;Pandas                                    Docker;Git
# 83419                    NaN               Docker;Git;Kubernetes;Terraform
#
#                        ToolsTechWantToWorkWith  \
# 3                                          NaN
# 123                         Ansible;Docker;Git
# 254                                        NaN
# 291                               Git;Unity 3D
# 339                                        NaN
# ...                                        ...
# 82849                               Docker;Git
# 82868                               Docker;Git
# 83048      Docker;Git;Kubernetes;Unreal Engine
# 83349                                      Git
# 83419  Ansible;Docker;Git;Kubernetes;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 3                                                    NaN
# 123                                                Emacs
# 254           Android Studio;Atom;NetBeans;Visual Studio
# 291    Android Studio;Atom;IntelliJ;Notepad++;Sublime...
# 339                     Visual Studio;Visual Studio Code
# ...                                                  ...
# 82849  IntelliJ;Sublime Text;Visual Studio Code;Webstorm
# 82868                                            PyCharm
# 83048  Android Studio;Notepad++;Vim;Visual Studio;Vis...
# 83349  Atom;IntelliJ;Notepad++;PyCharm;Visual Studio ...
# 83419  Android Studio;IntelliJ;Notepad++;Visual Studi...
#
#                             NEWCollabToolsWantToWorkWith  \
# 3                                                    NaN
# 123                                                Emacs
# 254                                                  NaN
# 291                                   Android Studio;Vim
# 339                                      IPython/Jupyter
# ...                                                  ...
# 82849                                  IntelliJ;Webstorm
# 82868                                            PyCharm
# 83048    Android Studio;Notepad++;Vim;Visual Studio Code
# 83349  Atom;IntelliJ;Notepad++;PyCharm;Visual Studio ...
# 83419                                 IntelliJ;Notepad++
#
#                                    OpSys  \
# 3                                Windows
# 123                          Linux-based
# 254                              Windows
# 291                              Windows
# 339                              Windows
# ...                                  ...
# 82849                        Linux-based
# 82868  Windows Subsystem for Linux (WSL)
# 83048  Windows Subsystem for Linux (WSL)
# 83349                        Linux-based
# 83419  Windows Subsystem for Linux (WSL)
#
#                                                 NEWStuck  \
# 3      Call a coworker or friend;Visit Stack Overflow...
# 123    Visit Stack Overflow;Google it;Do other work a...
# 254    Call a coworker or friend;Visit Stack Overflow...
# 291    Visit Stack Overflow;Google it;Watch help / tu...
# 339    Visit Stack Overflow;Google it;Watch help / tu...
# ...                                                  ...
# 82849  Call a coworker or friend;Visit Stack Overflow...
# 82868  Call a coworker or friend;Visit Stack Overflow...
# 83048  Call a coworker or friend;Visit Stack Overflow...
# 83349  Call a coworker or friend;Visit Stack Overflow...
# 83419  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSites             SOVisitFreq SOAccount  \
# 3                     Stack Overflow   Daily or almost daily       Yes
# 123                   Stack Overflow   Daily or almost daily       Yes
# 254    Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 291    Stack Overflow;Stack Exchange    A few times per week       Yes
# 339    Stack Overflow;Stack Exchange  Multiple times per day       Yes
# ...                              ...                     ...       ...
# 82849  Stack Overflow;Stack Exchange    A few times per week       Yes
# 82868                 Stack Overflow   Daily or almost daily       Yes
# 83048  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 83349  Stack Overflow;Stack Exchange    A few times per week        No
# 83419  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                               SOPartFreq          SOComm  \
# 3                                  Daily or almost daily         Neutral
# 123                                 A few times per week         Neutral
# 254                  Less than once per month or monthly         Neutral
# 291                  Less than once per month or monthly   Yes, somewhat
# 339                                 A few times per week   Yes, somewhat
# ...                                                  ...             ...
# 82849  I have never participated in Q&A on Stack Over...  No, not really
# 82868  I have never participated in Q&A on Stack Over...  No, not at all
# 83048                Less than once per month or monthly  No, not really
# 83349                                                NaN         Neutral
# 83419                    A few times per month or weekly   Yes, somewhat
#
#       NEWOtherComms                 Age Gender Trans  \
# 3                No     35-44 years old    Man    No
# 123              No     25-34 years old    Man    No
# 254              No     18-24 years old    Man    No
# 291              No  Under 18 years old    Man    No
# 339             Yes     18-24 years old    Man   Yes
# ...             ...                 ...    ...   ...
# 82849            No     25-34 years old  Woman    No
# 82868           Yes     25-34 years old  Woman    No
# 83048            No     18-24 years old    Man    No
# 83349            No     18-24 years old  Woman    No
# 83419           Yes     35-44 years old    Man    No
#
#                               Sexuality                     Ethnicity  \
# 3               Straight / Heterosexual  White or of European descent
# 123                                 NaN                           NaN
# 254             Straight / Heterosexual  White or of European descent
# 291             Straight / Heterosexual  White or of European descent
# 339             Straight / Heterosexual  White or of European descent
# ...                                 ...                           ...
# 82849  Straight / Heterosexual;Bisexual  White or of European descent
# 82868                          Bisexual  White or of European descent
# 83048           Straight / Heterosexual  White or of European descent
# 83349           Straight / Heterosexual  White or of European descent
# 83419           Straight / Heterosexual  White or of European descent
#
#                      Accessibility  \
# 3      I am deaf / hard of hearing
# 123                            NaN
# 254              None of the above
# 291              None of the above
# 339              None of the above
# ...                            ...
# 82849            None of the above
# 82868            None of the above
# 83048            None of the above
# 83349            None of the above
# 83419            None of the above
#
#                                             MentalHealth  \
# 3                                                    NaN
# 123                                                  NaN
# 254                                    None of the above
# 291                                    None of the above
# 339                                    None of the above
# ...                                                  ...
# 82849                                  None of the above
# 82868  I have a concentration and/or memory disorder ...
# 83048                                  None of the above
# 83349                                  None of the above
# 83419                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 123    Appropriate in length                        Easy              59676.0
# 254    Appropriate in length  Neither easy nor difficult                  NaN
# 291    Appropriate in length                        Easy                  NaN
# 339    Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 82849  Appropriate in length                        Easy              98878.0
# 82868  Appropriate in length                        Easy                  NaN
# 83048              Too short                        Easy              57072.0
# 83349  Appropriate in length                        Easy                  NaN
# 83419  Appropriate in length                        Easy              83236.0
#
# [808 rows x 48 columns]

# %%
# Ensure to display all rows
pd.set_option('display.max_rows',200)
# get the value_counts
devs_per_country = survey_df["Country"].value_counts()
devs_per_country
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# Turkey                                                   1054
# Switzerland                                               922
# Israel                                                    913
# Iran, Islamic Republic of...                              900
# Pakistan                                                  838
# Austria                                                   808
# Czech Republic                                            792
# Ukraine                                                   770
# Bangladesh                                                704
# Belgium                                                   697
# Mexico                                                    695
# Romania                                                   650
# Indonesia                                                 632
# Greece                                                    603
# Norway                                                    602
# Denmark                                                   599
# Argentina                                                 587
# South Africa                                              571
# Portugal                                                  530
# Finland                                                   528
# New Zealand                                               522
# Egypt                                                     521
# Hungary                                                   478
# Japan                                                     429
# Nigeria                                                   409
# Bulgaria                                                  402
# Sri Lanka                                                 396
# Viet Nam                                                  386
# Ireland                                                   386
# Philippines                                               382
# Colombia                                                  381
# Singapore                                                 339
# Nepal                                                     337
# Malaysia                                                  333
# Serbia                                                    310
# Taiwan                                                    302
# Kenya                                                     263
# Slovakia                                                  252
# Croatia                                                   250
# Slovenia                                                  235
# Chile                                                     230
# Lithuania                                                 208
# Morocco                                                   204
# Hong Kong (S.A.R.)                                        198
# South Korea                                               189
# Thailand                                                  184
# United Arab Emirates                                      182
# Belarus                                                   165
# Georgia                                                   161
# Tunisia                                                   150
# Peru                                                      147
# Uruguay                                                   144
# Saudi Arabia                                              137
# Estonia                                                   130
# Bosnia and Herzegovina                                    130
# Lebanon                                                   113
# Latvia                                                    107
# Venezuela, Bolivarian Republic of...                      104
# Dominican Republic                                        104
# Ecuador                                                   103
# Armenia                                                    92
# Ghana                                                      91
# Costa Rica                                                 77
# Iraq                                                       76
# Albania                                                    73
# Jordan                                                     72
# Ethiopia                                                   69
# Uzbekistan                                                 68
# Kazakhstan                                                 65
# Afghanistan                                                65
# Azerbaijan                                                 64
# Uganda                                                     63
# Guatemala                                                  58
# Cyprus                                                     56
# Republic of Moldova                                        55
# Myanmar                                                    55
# The former Yugoslav Republic of Macedonia                  54
# Republic of Korea                                          54
# Nomadic                                                    54
# Syrian Arab Republic                                       51
# Luxembourg                                                 51
# Bolivia                                                    48
# Paraguay                                                   47
# Algeria                                                    46
# Kosovo                                                     45
# Iceland                                                    43
# United Republic of Tanzania                                43
# Malta                                                      42
# Cameroon                                                   38
# Zimbabwe                                                   36
# Cambodia                                                   35
# Cuba                                                       34
# Rwanda                                                     34
# El Salvador                                                32
# Panama                                                     31
# Mauritius                                                  31
# Qatar                                                      29
# Kuwait                                                     29
# Bahrain                                                    28
# Senegal                                                    28
# Sudan                                                      27
# Angola                                                     27
# Palestine                                                  25
# Honduras                                                   24
# Zambia                                                     22
# Mongolia                                                   21
# Kyrgyzstan                                                 21
# Jamaica                                                    20
# Yemen                                                      20
# Oman                                                       20
# Trinidad and Tobago                                        20
# Nicaragua                                                  18
# Madagascar                                                 18
# Montenegro                                                 17
# Côte d'Ivoire                                              17
# Maldives                                                   16
# Benin                                                      15
# Turkmenistan                                               13
# Mozambique                                                 12
# Congo, Republic of the...                                  12
# Barbados                                                   12
# Namibia                                                    12
# Andorra                                                    12
# Libyan Arab Jamahiriya                                     11
# Malawi                                                     11
# Swaziland                                                  10
# Democratic Republic of the Congo                           10
# Tajikistan                                                  9
# Bahamas                                                     7
# Guyana                                                      7
# Togo                                                        7
# Somalia                                                     7
# Botswana                                                    6
# North Korea                                                 6
# Cape Verde                                                  6
# Isle of Man                                                 5
# Haiti                                                       5
# Bhutan                                                      5
# Belize                                                      5
# Suriname                                                    5
# Mauritania                                                  5
# Burundi                                                     5
# Burkina Faso                                                4
# Lesotho                                                     4
# Fiji                                                        4
# Lao People's Democratic Republic                            4
# Liberia                                                     3
# Central African Republic                                    3
# Djibouti                                                    3
# Niger                                                       3
# Saint Lucia                                                 3
# Chad                                                        2
# San Marino                                                  2
# Monaco                                                      2
# Gambia                                                      2
# Guinea                                                      2
# Mali                                                        2
# Micronesia, Federated States of...                          2
# Sierra Leone                                                2
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Brunei Darussalam                                           1
# Dominica                                                    1
# Name: Country, dtype: int64

# %%
# Get top 25 countries
devs_per_country.head(25)
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# Turkey                                                   1054
# Switzerland                                               922
# Israel                                                    913
# Iran, Islamic Republic of...                              900
# Pakistan                                                  838
# Austria                                                   808
# Czech Republic                                            792
# Ukraine                                                   770
# Bangladesh                                                704
# Belgium                                                   697
# Name: Country, dtype: int64

# %% [markdown]
# That's it for today! Thanks for watching and happy coding :)!

# %% [markdown]
# # Part 3

# %%
survey_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# ### Slicing

# %%
survey_df.loc[0:49, 'Gender']
# Out:
# 0                                                   Man
# 1                                                   Man
# 2                                                   Man
# 3                                                   Man
# 4                                                   Man
# 5                                     Prefer not to say
# 6                                     Prefer not to say
# 7                                                 Woman
# 8                                                   Man
# 9                                                   Man
# 10                                                  Man
# 11                                                  Man
# 12                                                  Man
# 13                                    Prefer not to say
# 14                                                  Man
# 15                                                  Man
# 16                                                  Man
# 17                                                  Man
# 18                                                  Man
# 19                                                  Man
# 20                                                  Man
# 21                                                  Man
# 22                                                  Man
# 23                                                  Man
# 24                                                  Man
# 25    Non-binary, genderqueer, or gender non-conforming
# 26                                                  Man
# 27                                                  Man
# 28                                                  Man
# 29                                                  Man
# 30                                                  Man
# 31                                                  Man
# 32                                                  Man
# 33                                                  Man
# 34                                                  Man
# 35                                                  Man
# 36                                                  Man
# 37                                                  Man
# 38                                                  Man
# 39                                                Woman
# 40                                                  Man
# 41                                                  Man
# 42                                                  Man
# 43                                                  Man
# 44                                                Woman
# 45                                                  Man
# 46                                                  Man
# 47                                                  Man
# 48                                                  Man
# 49                                                  Man
# Name: Gender, dtype: object

# %%
survey_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
survey_df.loc[0:49, 'MainBranch':'Country']
# Out:
#                                            MainBranch  \
# 0                      I am a developer by profession
# 1              I am a student who is learning to code
# 2   I am not primarily a developer, but I write co...
# 3                      I am a developer by profession
# 4                      I am a developer by profession
# 5              I am a student who is learning to code
# 6                         I code primarily as a hobby
# 7              I am a student who is learning to code
# 8                      I am a developer by profession
# 9                      I am a developer by profession
# 10                     I am a developer by profession
# 11                     I am a developer by profession
# 12                     I am a developer by profession
# 13             I am a student who is learning to code
# 14  I used to be a developer by profession, but no...
# 15             I am a student who is learning to code
# 16                     I am a developer by profession
# 17                     I am a developer by profession
# 18  I am not primarily a developer, but I write co...
# 19  I used to be a developer by profession, but no...
# 20                     I am a developer by profession
# 21             I am a student who is learning to code
# 22             I am a student who is learning to code
# 23                     I am a developer by profession
# 24                     I am a developer by profession
# 25  I am not primarily a developer, but I write co...
# 26  I am not primarily a developer, but I write co...
# 27                     I am a developer by profession
# 28                     I am a developer by profession
# 29                     I am a developer by profession
# 30                        I code primarily as a hobby
# 31                     I am a developer by profession
# 32                     I am a developer by profession
# 33                     I am a developer by profession
# 34                     I am a developer by profession
# 35                     I am a developer by profession
# 36                     I am a developer by profession
# 37                     I am a developer by profession
# 38             I am a student who is learning to code
# 39             I am a student who is learning to code
# 40                     I am a developer by profession
# 41  I am not primarily a developer, but I write co...
# 42  I am not primarily a developer, but I write co...
# 43                        I code primarily as a hobby
# 44                     I am a developer by profession
# 45                     I am a developer by profession
# 46                        I code primarily as a hobby
# 47  I used to be a developer by profession, but no...
# 48                     I am a developer by profession
# 49             I am a student who is learning to code
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 1                                  Student, full-time
# 2                                  Student, full-time
# 3                                  Employed full-time
# 4   Independent contractor, freelancer, or self-em...
# 5                                  Student, part-time
# 6                                 I prefer not to say
# 7                                  Student, full-time
# 8                                  Employed part-time
# 9                                  Employed full-time
# 10                                 Employed full-time
# 11                                 Employed full-time
# 12                                 Employed full-time
# 13                                 Employed full-time
# 14                 Not employed, but looking for work
# 15                                 Student, full-time
# 16                                 Employed full-time
# 17                                 Employed full-time
# 18                                I prefer not to say
# 19                                 Employed full-time
# 20                                 Student, full-time
# 21                                 Student, full-time
# 22                                 Student, full-time
# 23                                 Employed full-time
# 24                                 Employed full-time
# 25                                 Employed full-time
# 26                                 Employed full-time
# 27                                 Employed full-time
# 28  Independent contractor, freelancer, or self-em...
# 29                                 Employed full-time
# 30                                I prefer not to say
# 31                                 Employed full-time
# 32                 Not employed, but looking for work
# 33                                 Employed full-time
# 34                                 Employed full-time
# 35                                 Employed full-time
# 36                                 Employed full-time
# 37                                 Employed full-time
# 38                 Not employed, but looking for work
# 39                                 Student, part-time
# 40                                 Employed full-time
# 41                                 Employed full-time
# 42                                 Student, full-time
# 43                 Not employed, but looking for work
# 44                                 Employed full-time
# 45                                 Employed full-time
# 46                                I prefer not to say
# 47                                            Retired
# 48                                 Employed full-time
# 49                                 Student, full-time
#
#                                               Country
# 0                                            Slovakia
# 1                                         Netherlands
# 2                                  Russian Federation
# 3                                             Austria
# 4   United Kingdom of Great Britain and Northern I...
# 5                            United States of America
# 6                            United States of America
# 7                                            Malaysia
# 8                                               India
# 9                                              Sweden
# 10  United Kingdom of Great Britain and Northern I...
# 11                                              Spain
# 12                                            Germany
# 13                                               Peru
# 14  United Kingdom of Great Britain and Northern I...
# 15                           United States of America
# 16                                             Turkey
# 17                                             Canada
# 18                                          Singapore
# 19                                             Brazil
# 20                                            Germany
# 21                                             Sweden
# 22                                              India
# 23                                             France
# 24                                            Germany
# 25                                            Germany
# 26                                        Switzerland
# 27  United Kingdom of Great Britain and Northern I...
# 28  United Kingdom of Great Britain and Northern I...
# 29                                 Russian Federation
# 30                                             Malawi
# 31                                             Israel
# 32                                             Poland
# 33                                             Turkey
# 34                                            Ukraine
# 35                                            Germany
# 36                           United States of America
# 37                           United States of America
# 38                                           Viet Nam
# 39                                              India
# 40                                           Portugal
# 41                                             France
# 42                                              Italy
# 43  United Kingdom of Great Britain and Northern I...
# 44                                             France
# 45                                             Brazil
# 46                                               Peru
# 47                           United States of America
# 48                                           Bulgaria
# 49                                              India

# %% [markdown]
# ### Indexing

# %%
peoples_df
# Out:
#   First_Name Last_Name                         Email
# 0        Max     Mason    max_mason939sd39@gmail.com
# 1       John       Doe     john_doe939ds39@gmail.com
# 2       Anna     Adams  anna_adams284s72d8@gmail.com

# %%
peoples_df.Email
# Out:
# 0      max_mason939sd39@gmail.com
# 1       john_doe939ds39@gmail.com
# 2    anna_adams284s72d8@gmail.com
# Name: Email, dtype: object

# %%
peoples_df = peoples_df.set_index('Email')
peoples_df
# Out:
#                              First_Name Last_Name
# Email
# max_mason939sd39@gmail.com          Max     Mason
# john_doe939ds39@gmail.com          John       Doe
# anna_adams284s72d8@gmail.com       Anna     Adams

# %%
peoples_df.loc['john_doe939ds39@gmail.com', 'Last_Name']
# Out:
# 'Doe'

# %%
peoples_df.iloc[0]
# Out:
# First_Name      Max
# Last_Name     Mason
# Name: max_mason939sd39@gmail.com, dtype: object

# %% [markdown]
# That's it for today! Happy coding & studying!

# %% [markdown]
# ## Part 4

# %%
import pandas as pd

# %%
survey_df = pd.read_csv("./Data/survey_results_public.csv",index_col="ResponseId")
schema_df = pd.read_csv("./Data/survey_results_schema.csv")

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

survey_df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  ConvertedCompYearly
# ResponseId
# 1                                 Easy              62268.0
# 2                                 Easy                  NaN
# 3                                 Easy                  NaN
# 4           Neither easy nor difficult                  NaN
# 5                                 Easy                  NaN

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
schema_df = pd.read_csv("./Data/survey_results_schema.csv", index_col="qname")
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
# DevType              QID31  Which of the following describes your current ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# Language            QID233  Which <b>programming, scripting, and markup la...
# Database            QID262  Which <b>database environments </b>have you do...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# Age                 QID127                                  What is your age?
# Gender              QID122  Which of the following describe you, if any? P...
# Trans               QID153                    Do you identify as transgender?
# Sexuality           QID136  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Accessibility       QID124  Which of the following describe you, if any? P...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
#
#                     force_resp    type selector
# qname
# S0                       False      DB       TB
# MetaInfo                 False    Meta  Browser
# S1                       False      DB       TB
# MainBranch                True      MC     SAVR
# Employment               False      MC     MAVR
# Country                   True      MC       DL
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# S2                       False      DB       TB
# EdLevel                  False      MC     SAVR
# Age1stCode               False      MC     MAVR
# LearnCode                False      MC     MAVR
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL
# DevType                  False      MC     MAVR
# OrgSize                  False      MC     MAVR
# Currency                  True      MC       SB
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# S3                       False      DB       TB
# Language                 False  Matrix   Likert
# Database                 False  Matrix   Likert
# Platform                 False  Matrix   Likert
# Webframe                 False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# ToolsTech                False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# S4                       False      DB       TB
# NEWSOSites               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOAccount                False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# S5                       False      DB       TB
# Age                      False      MC     MAVR
# Gender                   False      MC     MAVR
# Trans                    False      MC     MAVR
# Sexuality                False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Accessibility            False      MC     MAVR
# MentalHealth             False      MC     MAVR
# S6                       False      DB       TB
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR

# %%
schema_df.loc["SOAccount"]
# Out:
# qid                                          QID101
# question      Do you have a Stack Overflow account?
# force_resp                                    False
# type                                             MC
# selector                                       MAVR
# Name: SOAccount, dtype: object

# %%
schema_df.loc["SOAccount", "question"]
# Out:
# 'Do you have a Stack Overflow account?'

# %%
schema_df.sort_index()
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Gender              QID122  Which of the following describe you, if any? P...
# Language            QID233  Which <b>programming, scripting, and markup la...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# MainBranch            QID2  Which of the following options best describes ...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MetaInfo             QID12                                  Browser Meta Info
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# OpSys                QID71  What is the primary operating system in which ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# SurveyLength        QID132  How do you feel about the length of the survey...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# Trans               QID153                    Do you identify as transgender?
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# US_State              QID7  <p>In which state or territory of the USA do y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
#
#                     force_resp    type selector
# qname
# Accessibility            False      MC     MAVR
# Age                      False      MC     MAVR
# Age1stCode               False      MC     MAVR
# CompFreq                 False      MC     MAVR
# CompTotal                False      TE       SL
# Country                   True      MC       DL
# Currency                  True      MC       SB
# Database                 False  Matrix   Likert
# DevType                  False      MC     MAVR
# EdLevel                  False      MC     SAVR
# Employment               False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Gender                   False      MC     MAVR
# Language                 False  Matrix   Likert
# LearnCode                False      MC     MAVR
# MainBranch                True      MC     SAVR
# MentalHealth             False      MC     MAVR
# MetaInfo                 False    Meta  Browser
# MiscTech                 False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWSOSites               False      MC     MAVR
# NEWStuck                 False      MC     MAVR
# OpSys                    False      MC     SAVR
# OrgSize                  False      MC     MAVR
# Platform                 False  Matrix   Likert
# S0                       False      DB       TB
# S1                       False      DB       TB
# S2                       False      DB       TB
# S3                       False      DB       TB
# S4                       False      DB       TB
# S5                       False      DB       TB
# S6                       False      DB       TB
# SOAccount                False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# Sexuality                False      MC     MAVR
# SurveyEase               False      MC     MAVR
# SurveyLength             False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# Trans                    False      MC     MAVR
# UK_Country               False      MC       DL
# US_State                 False      MC       DL
# Webframe                 False  Matrix   Likert
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL

# %%
schema_df.sort_index(ascending=False)
# Out:
#                        qid                                           question  \
# qname
# YearsCodePro         QID34  NOT including education, how many years have y...
# YearsCode            QID32  Including any education, how many years have y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# Trans               QID153                    Do you identify as transgender?
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOAccount           QID101              Do you have a Stack Overflow account?
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# OrgSize              QID29  Approximately how many people are employed by ...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# MetaInfo             QID12                                  Browser Meta Info
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MainBranch            QID2  Which of the following options best describes ...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# Language            QID233  Which <b>programming, scripting, and markup la...
# Gender              QID122  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Employment           QID24  Which of the following best describes your cur...
# EdLevel              QID25  Which of the following best describes the high...
# DevType              QID31  Which of the following describes your current ...
# Database            QID262  Which <b>database environments </b>have you do...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Country               QID6  Where do you live? <span style="font-weight: b...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# Age1stCode          QID149  At what age did you write your first line of c...
# Age                 QID127                                  What is your age?
# Accessibility       QID124  Which of the following describe you, if any? P...
#
#                     force_resp    type selector
# qname
# YearsCodePro             False      MC       DL
# YearsCode                False      MC       DL
# Webframe                 False  Matrix   Likert
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# Trans                    False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR
# Sexuality                False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOAccount                False      MC     MAVR
# S6                       False      DB       TB
# S5                       False      DB       TB
# S4                       False      DB       TB
# S3                       False      DB       TB
# S2                       False      DB       TB
# S1                       False      DB       TB
# S0                       False      DB       TB
# Platform                 False  Matrix   Likert
# OrgSize                  False      MC     MAVR
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# NEWSOSites               False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWCollabTools           False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# MetaInfo                 False    Meta  Browser
# MentalHealth             False      MC     MAVR
# MainBranch                True      MC     SAVR
# LearnCode                False      MC     MAVR
# Language                 False  Matrix   Likert
# Gender                   False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Employment               False      MC     MAVR
# EdLevel                  False      MC     SAVR
# DevType                  False      MC     MAVR
# Database                 False  Matrix   Likert
# Currency                  True      MC       SB
# Country                   True      MC       DL
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# Age1stCode               False      MC     MAVR
# Age                      False      MC     MAVR
# Accessibility            False      MC     MAVR

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
# DevType              QID31  Which of the following describes your current ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# CompTotal            QID51  What is your current total compensation (salar...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# Language            QID233  Which <b>programming, scripting, and markup la...
# Database            QID262  Which <b>database environments </b>have you do...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# OpSys                QID71  What is the primary operating system in which ...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOComm              QID106  Do you consider yourself a member of the Stack...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# Age                 QID127                                  What is your age?
# Gender              QID122  Which of the following describe you, if any? P...
# Trans               QID153                    Do you identify as transgender?
# Sexuality           QID136  Which of the following describe you, if any? P...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Accessibility       QID124  Which of the following describe you, if any? P...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
#
#                     force_resp    type selector
# qname
# S0                       False      DB       TB
# MetaInfo                 False    Meta  Browser
# S1                       False      DB       TB
# MainBranch                True      MC     SAVR
# Employment               False      MC     MAVR
# Country                   True      MC       DL
# US_State                 False      MC       DL
# UK_Country               False      MC       DL
# S2                       False      DB       TB
# EdLevel                  False      MC     SAVR
# Age1stCode               False      MC     MAVR
# LearnCode                False      MC     MAVR
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL
# DevType                  False      MC     MAVR
# OrgSize                  False      MC     MAVR
# Currency                  True      MC       SB
# CompTotal                False      TE       SL
# CompFreq                 False      MC     MAVR
# S3                       False      DB       TB
# Language                 False  Matrix   Likert
# Database                 False  Matrix   Likert
# Platform                 False  Matrix   Likert
# Webframe                 False  Matrix   Likert
# MiscTech                 False  Matrix   Likert
# ToolsTech                False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# OpSys                    False      MC     SAVR
# NEWStuck                 False      MC     MAVR
# S4                       False      DB       TB
# NEWSOSites               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# SOAccount                False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOComm                   False      MC     MAVR
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# S5                       False      DB       TB
# Age                      False      MC     MAVR
# Gender                   False      MC     MAVR
# Trans                    False      MC     MAVR
# Sexuality                False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Accessibility            False      MC     MAVR
# MentalHealth             False      MC     MAVR
# S6                       False      DB       TB
# SurveyLength             False      MC     MAVR
# SurveyEase               False      MC     MAVR

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# Ethnicity           QID126  Which of the following describe you, if any? P...
# Gender              QID122  Which of the following describe you, if any? P...
# Language            QID233  Which <b>programming, scripting, and markup la...
# LearnCode           QID276  How did you learn to code? Select all that apply.
# MainBranch            QID2  Which of the following options best describes ...
# MentalHealth        QID125  Which of the following describe you, if any? P...
# MetaInfo             QID12                                  Browser Meta Info
# MiscTech            QID265  Which <b>other frameworks and libraries</b> ha...
# NEWCollabTools      QID274  Which <strong>development environments</strong...
# NEWOtherComms       QID267  Are you a member of any other online developer...
# NEWOtherCommsNames  QID268  Please name up to 5 other online developer com...
# NEWSOSites          QID266  Which of the following Stack Overflow sites ha...
# NEWStuck            QID243  What do you do when you get stuck on a problem...
# OpSys                QID71  What is the primary operating system in which ...
# OrgSize              QID29  Approximately how many people are employed by ...
# Platform            QID263  Which <b>cloud platforms</b> have you done ext...
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# S3                   QID61  <span style="font-size:22px; font-family: aria...
# S4                   QID91  <span style="font-size:22px; font-family: aria...
# S5                  QID121  <span style="font-size:22px; font-family: aria...
# S6                  QID131  <span style="font-size:22px;"><strong>Final Qu...
# SOAccount           QID101              Do you have a Stack Overflow account?
# SOComm              QID106  Do you consider yourself a member of the Stack...
# SOPartFreq          QID102  How frequently would you say you participate i...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# SurveyLength        QID132  How do you feel about the length of the survey...
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# Trans               QID153                    Do you identify as transgender?
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# US_State              QID7  <p>In which state or territory of the USA do y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# YearsCode            QID32  Including any education, how many years have y...
# YearsCodePro         QID34  NOT including education, how many years have y...
#
#                     force_resp    type selector
# qname
# Accessibility            False      MC     MAVR
# Age                      False      MC     MAVR
# Age1stCode               False      MC     MAVR
# CompFreq                 False      MC     MAVR
# CompTotal                False      TE       SL
# Country                   True      MC       DL
# Currency                  True      MC       SB
# Database                 False  Matrix   Likert
# DevType                  False      MC     MAVR
# EdLevel                  False      MC     SAVR
# Employment               False      MC     MAVR
# Ethnicity                False      MC     MAVR
# Gender                   False      MC     MAVR
# Language                 False  Matrix   Likert
# LearnCode                False      MC     MAVR
# MainBranch                True      MC     SAVR
# MentalHealth             False      MC     MAVR
# MetaInfo                 False    Meta  Browser
# MiscTech                 False  Matrix   Likert
# NEWCollabTools           False  Matrix   Likert
# NEWOtherComms            False      MC     MAVR
# NEWOtherCommsNames       False  Matrix   Likert
# NEWSOSites               False      MC     MAVR
# NEWStuck                 False      MC     MAVR
# OpSys                    False      MC     SAVR
# OrgSize                  False      MC     MAVR
# Platform                 False  Matrix   Likert
# S0                       False      DB       TB
# S1                       False      DB       TB
# S2                       False      DB       TB
# S3                       False      DB       TB
# S4                       False      DB       TB
# S5                       False      DB       TB
# S6                       False      DB       TB
# SOAccount                False      MC     MAVR
# SOComm                   False      MC     MAVR
# SOPartFreq               False      MC     MAVR
# SOVisitFreq              False      MC     MAVR
# Sexuality                False      MC     MAVR
# SurveyEase               False      MC     MAVR
# SurveyLength             False      MC     MAVR
# ToolsTech                False  Matrix   Likert
# Trans                    False      MC     MAVR
# UK_Country               False      MC       DL
# US_State                 False      MC       DL
# Webframe                 False  Matrix   Likert
# YearsCode                False      MC       DL
# YearsCodePro             False      MC       DL

# %% [markdown]
# ## Part 5
